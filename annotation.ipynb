# %% [markdown]
# ## Annotations loaded from Google drive

# %% [markdown]
# ## Step 0: Environment set up

# %%
from conn import connect2Googlesheet,get_relevant_documents
import pandas as pd

# %% [markdown]
# ## Step 1: Load data into a dataframe

# %%
spreadsheet = connect2Googlesheet()

# Select the worksheet: relevance
worksheet = spreadsheet.get_worksheet(3)  

# Get all records as a list of dictionaries
data = worksheet.get_all_records()

# Convert to Pandas DataFrame
df_relevance = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 spreadsheet = connect2Googlesheet()
#       3 # Select the worksheet: relevance
#       4 worksheet = spreadsheet.get_worksheet(3)
#
# File ~/Downloads/25Spring/IDS 798 Capstone Project/Neo4j/GraphRAG_experiments/conn.py:15, in connect2Googlesheet()
#      13 if creds_path is None:
#      14     raise ValueError("The environment variable GOOGLE_SHEET_CREDS is not set.")
# ---> 15 creds = ServiceAccountCredentials.from_json_keyfile_name(creds_path, scope)
#      16 client = gspread.authorize(creds)
#      17 sheet_url = 'https://docs.google.com/spreadsheets/d/1GRStLZdPvZTN-DDcxND3xaYaHGGl-wVCQxWdsFRhsqs/edit?gid=408470182#gid=408470182'
#
# File ~/Downloads/25Spring/IDS 798 Capstone Project/Neo4j/GraphRAG_experiments/.venv/lib/python3.12/site-packages/oauth2client/service_account.py:219, in ServiceAccountCredentials.from_json_keyfile_name(cls, filename, scopes, token_uri, revoke_uri)
#     193 @classmethod
#     194 def from_json_keyfile_name(cls, filename, scopes='',
#     195                            token_uri=None, revoke_uri=None):
#     197     """Factory constructor from JSON keyfile by name.
#     198
#     199     Args:
#    (...)
#     217             the keyfile.
#     218     """
# --> 219     with open(filename, 'r') as file_obj:
#     220         client_credentials = json.load(file_obj)
#     221     return cls._from_parsed_json_keyfile(client_credentials, scopes,
#     222                                          token_uri=token_uri,
#     223                                          revoke_uri=revoke_uri)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'reliable-mode-399404-dc4b73f57296.json # DO NOT CHANGE HERE!!!'

# %% [markdown]
# ## Step 2: Keep relevant docs for each question

# %%
relevant_docs_all = {}
for question in df_relevance.columns[1:]:  # Skip the first column which is 'Document'
    relevant_docs_all[question] = get_relevant_documents(df_relevance, question)
# Convert the sets to lists and then join them into strings
for question in relevant_docs_all:
    relevant_docs_all[question] = ', '.join(relevant_docs_all[question])

# Convert the dictionary to a DataFrame
relevant_docs_df = pd.DataFrame(list(relevant_docs_all.items())[1:], columns=['Question', 'Docs'])

# save relevant_docs_df as dataframe
#relevant_docs_df.to_csv('relevant_docs.csv', index=True)
relevant_docs_df
# Out:
#         Question                                   Docs
# 0    Relevace Q1                         ROSE, ACURASYS
# 1    Relevace Q2                         ROSE, ACURASYS
# 2    Relevace Q3                                   ROSE
# 3    Relevace Q4                                   ROSE
# 4    Relevace Q5                                  FACTT
# 5    Relevace Q6                                  FACTT
# 6    Relevace Q7                                ARDSNet
# 7    Relevace Q8                                ARDSNet
# 8    Relevace Q9                                PROSEVA
# 9   Relevace Q10                              OSCILLATE
# 10  Relevace Q11  ADRENAL, APPROCCHSS, ANNANE, CORTICUS
# 11  Relevace Q12  ADRENAL, APPROCCHSS, ANNANE, CORTICUS
# 12  Relevace Q13  ADRENAL, APPROCCHSS, ANNANE, CORTICUS
# 13  Relevace Q14  ADRENAL, APPROCCHSS, ANNANE, CORTICUS
# 14  Relevace Q15                                   HEAT
# 15  Relevace Q16                 PROWESS, PROWESS-SHOCK
# 16  Relevace Q17                           ALBIOS, SAFE
# 17  Relevace Q18                           ALBIOS, SAFE
# 18  Relevace Q19                                ProMISe
# 19  Relevace Q20                 PROWESS, PROWESS-SHOCK
# 20  Relevace Q21                              TTM2, TTM
# 21  Relevace Q22                              TTM2, TTM
# 22  Relevace Q23                                   HACA
# 23  Relevace Q24                                AID-ICU
# 24  Relevace Q25                               MIND-USA
# 25  RelevanceQ26                              SPICE III
# 26  RelevanceQ27                              SPICE III
# 27  RelevanceQ28                                 SEDCOM
# 28  RelevanceQ29                                 SEDCOM
# 29  RelevanceQ30                                 SEDCOM
# 30  RelevanceQ31                               LCOTARDS
# 31  RelevanceQ32                                 MHNOCA
# 32  RelevanceQ33                                 BTCSCA
# 33  RelevanceQ34                                 OTCSCA
# 34  RelevanceQ35                                DPSMVAS
# 35  RelevanceQ36
