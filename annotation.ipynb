# %% [markdown]
# ## Annotations loaded from Google drive

# %% [markdown]
# ## Step 0: Environment set up

# %%
from conn import connect2Googlesheet,get_relevant_documents
import pandas as pd # type: ignore
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Step 1: Load data into a dataframe

# %%
spreadsheet = connect2Googlesheet()

# Select the worksheet: relevance
worksheet = spreadsheet.get_worksheet(3)  

# Get all records as a list of dictionaries
data = worksheet.get_all_records()

# Convert to Pandas DataFrame
df_relevance = pd.DataFrame(data)

# %% [markdown]
# ## Step 2: Keep relevant docs for each question

# %%
relevant_docs_all = {}
for question in df_relevance.columns[1:]:  # Skip the first column which is 'Document'
    relevant_docs_all[question] = get_relevant_documents(df_relevance, question)
# Convert the sets to lists and then join them into strings
for question in relevant_docs_all:
    relevant_docs_all[question] = ', '.join(relevant_docs_all[question])

# Convert the dictionary to a DataFrame
relevant_docs_df = pd.DataFrame(list(relevant_docs_all.items())[2:38], columns=['Ques', 'Docs'])

# save relevant_docs_df as dataframe
relevant_docs_df.to_csv('./outputs/relevant_docs.csv', index=True)
relevant_docs_df
# Out:
#              Ques  \
# 0    Relevance Q1
# 1    Relevance Q2
# 2    Relevance Q3
# 3    Relevance Q4
# 4    Relevance Q5
# 5    Relevance Q6
# 6    Relevance Q7
# 7    Relevance Q8
# 8    Relevance Q9
# 9   Relevance Q10
# 10  Relevance Q11
# 11  Relevance Q12
# 12  Relevance Q13
# 13  Relevance Q14
# 14  Relevance Q15
# 15  Relevance Q16
# 16  Relevance Q17
# 17  Relevance Q18
# 18  Relevance Q19
# 19  Relevance Q20
# 20  Relevance Q21
# 21  Relevance Q22
# 22  Relevance Q23
# 23  Relevance Q24
# 24  Relevance Q25
# 25  Relevance Q26
# 26  Relevance Q27
# 27  Relevance Q28
# 28  Relevance Q29
# 29  Relevance Q30
# 30  Relevance Q31
# 31  Relevance Q32
# 32  Relevance Q33
# 33  Relevance Q34
# 34  Relevance Q35
# 35  Relevance Q36
#
#                                                                                                                                                  Docs
# 0                                                                     NBSARDS, ESCNBC, ROSE, ACURASYS, TOF-ARDS, PVOEMVRARDS, ENB, EDPMARDSLPMV, LSPA
# 1                                                             NBSARDS, ESCNBC, ROSE, ETSDMV, ACURASYS, TOF-ARDS, PVOEMVRARDS, ENB, EDPMARDSLPMV, LSPA
# 2                                                                                           NBSARDS, ESCNBC, ROSE, ETSDMV, PVOEMVRARDS, TOF-ARDS, ENB
# 3                                                                                           NBSARDS, ESCNBC, ROSE, ETSDMV, PVOEMVRARDS, TOF-ARDS, ENB
# 4                                                                                                        ARDSSRDRFMS, FMWSCPARDS, PAC-in-FACTT, FACTT
# 5                                                                                                        ARDSSRDRFMS, FMWSCPARDS, PAC-in-FACTT, FACTT
# 6                                                                                                       DLASPEEPvsARDSNET, DIHRFARDSNET, APV, ARDSNet
# 7                                                                                   DLASPEEPvsARDSNET, SPICE-III, APV, AID-ICU, DIHRFARDSNET, ARDSNet
# 8                                                                                              PROSEVA, CEIIUPPSARDS, ETSDMV, PPATDSHMA, EDPMARDSLPMV
# 9                                                                                            SEDCOM, HDDSICU, SPICE-III, OSCILLATE, AID-ICU, MIND-USA
# 10                                                                        SEDCOM, ANNANE, SPICE-III, ADRENAL, CORTICUS, APPROCCHSS, AID-ICU, MIND-USA
# 11  SEDCOM, HDDSICU, ANNANE, RDSCI, SPICE-III, ETSDMV, SMDLTSWCI, DDMLSMVICP, ADRENAL, EDvsLSMENDS, CORTICUS, APPROCCHSS, AID-ICU, MIND-USA, ESDDVCIP
# 12                                                                                                              CORTICUS, APPROCCHSS, ADRENAL, ANNANE
# 13                                                                                                              CORTICUS, APPROCCHSS, ADRENAL, ANNANE
# 14                                                                                                                                     ESDDVCIP, HEAT
# 15                                                                                                                   PROWESS, ESDDVCIP, PROWESS-SHOCK
# 16                                                                                                                           RUSGATICUD, SAFE, ALBIOS
# 17                                                                                                                                       SAFE, ALBIOS
# 18                                                                                                                       RUSGATICUD, ProMISe, AID-ICU
# 19                                                                                                                   PROWESS, ESDDVCIP, PROWESS-SHOCK
# 20                                                                                                                                 AID-ICU, TTM, TTM2
# 21                                                                                                                                          TTM, TTM2
# 22                                                                                                                                     ESDDVCIP, HACA
# 23                                                                            RUSGATICUD, SPICE-III, DDMLSMVICP, AID-ICU, RAEATICU, MIND-USA, AUDDICU
# 24                                                                                                             MIND-USA, SEDCOM, RAEATICU, RUSGATICUD
# 25                                          HDDSICU, RDSCI, ETSDMV, SPICE-III, SMDLTSWCI, DDMLSMVICP, EDvsLSMENDS, AID-ICU, MIND-USA, DIICU, ESDDVCIP
# 26                                     SEDCOM, RDSCI, RUSGATICUD, ETSDMV, SPICE-III, SMDLTSWCI, DDMLSMVICP, EDvsLSMENDS, RAEATICU, MIND-USA, ESDDVCIP
# 27                     SEDCOM, HDDSICU, RDSCI, RUSGATICUD, ETSDMV, SPICE-III, SMDLTSWCI, DDMLSMVICP, EDvsLSMENDS, RAEATICU, MIND-USA, DIICU, ESDDVCIP
# 28                                                     SEDCOM, HDDSICU, RDSCI, ETSDMV, SPICE-III, SMDLTSWCI, DDMLSMVICP, EDvsLSMENDS, DIICU, ESDDVCIP
# 29                                           SEDCOM, HDDSICU, RDSCI, ETSDMV, SPICE-III, SMDLTSWCI, DDMLSMVICP, EDvsLSMENDS, RAEATICU, DIICU, ESDDVCIP
# 30                                                                                                                                 ESDDVCIP, ESCPARDS
# 31                                                                                                                                 ESDDVCIP, LCOTARDS
# 32                                                                                                                                   ESDDVCIP, MHNOCA
# 33                                                                                                                                             BTCSCA
# 34                                                                                                               ESDDVCIP, SPICE-III, HDDSICU, OTCSCA
# 35                                   SEDCOM, HDDSICU, DPSMVAS, RDSCI, ETSDMV, SPICE-III, DDMLSMVICP, EDvsLSMENDS, RAEATICU, MIND-USA, DIICU, ESDDVCIP
