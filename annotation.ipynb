# %% [markdown]
# ## Annotations loaded from Google drive

# %% [markdown]
# ## Step 0: Environment set up

# %%
from conn import connect2Googlesheet, get_relevant_documents
import pandas as pd  # type: ignore

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Step 1: Load data into a dataframe

# %%
spreadsheet = connect2Googlesheet()

# Select the worksheet: relevance
worksheet = spreadsheet.get_worksheet(2)

# Get all records as a list of dictionaries
data = worksheet.get_all_records()

# Convert to Pandas DataFrame
df_relevance = pd.DataFrame(data)

# %% [markdown]
# ## Step 2: Keep relevant docs for each question

# %%
relevant_docs_all = {}
for question in df_relevance.columns[1:]:  # Skip the first column which is 'Document'
    relevant_docs_all[question] = get_relevant_documents(df_relevance, question)
# Convert the sets to lists and then join them into strings
for question in relevant_docs_all:
    relevant_docs_all[question] = ", ".join(relevant_docs_all[question])

# Convert the dictionary to a DataFrame
relevant_docs_df = pd.DataFrame(
    list(relevant_docs_all.items())[2:38], columns=["Ques", "Docs"]
)

# save relevant_docs_df as dataframe
relevant_docs_df.to_csv("./outputs/relevant_docs.csv", index=True)
relevant_docs_df
# Out:
#              Ques  \
# 0    Relevance Q1
# 1    Relevance Q2
# 2    Relevance Q3
# 3    Relevance Q4
# 4    Relevance Q5
# 5    Relevance Q6
# 6    Relevance Q7
# 7    Relevance Q8
# 8    Relevance Q9
# 9   Relevance Q10
# 10  Relevance Q11
# 11  Relevance Q12
# 12  Relevance Q13
# 13  Relevance Q14
# 14  Relevance Q15
# 15  Relevance Q16
# 16  Relevance Q17
# 17  Relevance Q18
# 18  Relevance Q19
# 19  Relevance Q20
# 20  Relevance Q21
# 21  Relevance Q22
# 22  Relevance Q23
# 23  Relevance Q24
# 24  Relevance Q25
# 25  Relevance Q26
# 26  Relevance Q27
# 27  Relevance Q28
# 28  Relevance Q29
# 29  Relevance Q30
# 30  Relevance Q31
# 31  Relevance Q32
# 32  Relevance Q33
# 33  Relevance Q34
# 34  Relevance Q35
# 35  Relevance Q36
#
#                                                                                                                                                                             Docs
# 0                                                                                                ENB, LSPA, NBSARDS, ACURASYS, ROSE, ESCNBC, EDPMARDSLPMV, PVOEMVRARDS, TOF-ARDS
# 1                                                                                        ETSDMV, ENB, LSPA, NBSARDS, ACURASYS, ROSE, ESCNBC, EDPMARDSLPMV, PVOEMVRARDS, TOF-ARDS
# 2                                                                                                                      ETSDMV, ENB, NBSARDS, ROSE, ESCNBC, PVOEMVRARDS, TOF-ARDS
# 3                                                                                                                      ETSDMV, ENB, NBSARDS, ROSE, ESCNBC, PVOEMVRARDS, TOF-ARDS
# 4                                                                                                                                   FMWSCPARDS, FACTT, PAC-in-FACTT, ARDSSRDRFMS
# 5                                                                                                                                   FMWSCPARDS, FACTT, PAC-in-FACTT, ARDSSRDRFMS
# 6                                                                                                                                  APV, ARDSNet, DLASPEEPvsARDSNET, DIHRFARDSNET
# 7                                                                                                              APV, ARDSNet, SPICE-III, AID-ICU, DLASPEEPvsARDSNET, DIHRFARDSNET
# 8                                                                                                                         ETSDMV, PROSEVA, CEIIUPPSARDS, EDPMARDSLPMV, PPATDSHMA
# 9                                                                                                                       HDDSICU, MIND-USA, OSCILLATE, SPICE-III, AID-ICU, SEDCOM
# 10                                                                        ANNANE, ADRENAL, MIND-USA, NEvsVP, HYPRESS, SPICE-III, PLMALDHSS, CORTICUS, AID-ICU, SEDCOM, APROCCHSS
# 11  ANNANE, ADRENAL, ETSDMV, DDMLSMVICP, HDDSICU, MIND-USA, NEvsVP, EDvsLSMENDS, ESDDVCIP, HYPRESS, SPICE-III, PLMALDHSS, CORTICUS, AID-ICU, SMDLTSWCI, SEDCOM, RDSCI, APROCCHSS
# 12                                                                                                              ANNANE, ADRENAL, HYPRESS, PLMALDHSS, CORTICUS, NEvsVP, APROCCHSS
# 13                                                                                                              ANNANE, ADRENAL, HYPRESS, PLMALDHSS, CORTICUS, NEvsVP, APROCCHSS
# 14                                                                                                                                                                ESDDVCIP, HEAT
# 15                                                                                                                                      ESDDVCIP, SADASS, PROWESS-SHOCK, PROWESS
# 16                                                                                                                              RUSGATICUD, FRESHS, ULS, SS3vsSS2, ALBIOS, EHPSS
# 17                                                                                                                                                                  SAFE, FRESHS
# 18                                                                                                                             RUSGATICUD, ProMISe, ARISE, AID-ICU, Rivers Trial
# 19                                                                                                                                      ESDDVCIP, SADASS, PROWESS-SHOCK, PROWESS
# 20                                                                           MPOHCAUSPITHRCA, CETHACA, THvsTN, SRRCTTHNPCAP, TTM, TTM2, ITMNCA, HNPCASR, VMOCA, TCAIHCA, HACA-LA
# 21                                                                           MPOHCAUSPITHRCA, CETHACA, THvsTN, SRRCTTHNPCAP, TTM, TTM2, ITMNCA, HNPCASR, VMOCA, TCAIHCA, HACA-LA
# 22                                                            MPOHCAUSPITHRCA, ESDDVCIP, CETHACA, THvsTN, SRRCTTHNPCAP, HACA, ITMNCA, SOPA-III, HNPCASR, VMOCA, TCAIHCA, HACA-LA
# 23                                                                   ATD, RUSGATICUD, MIND-USA, AUDDICU, AUPTICUPP, AMTD, DIICU, RAEATICU, SPICE-III, AID-ICU, RDSCI, DDMLSMVICP
# 24                                                           ATD, RUSGATICUD, MIND-USA, AUDDICU, AUPTICUPP, AMTD, DIICU, RAEATICU, SPICE-III, AID-ICU, SEDCOM, RDSCI, DDMLSMVICP
# 25                ETSDMV, ATD, HDDSICU, MIND-USA, AUDDICU, AUPTICUPP, EDvsLSMENDS, ESDDVCIP, RUSGATICUD, AMTD, DIICU, RAEATICU, SPICE-III, AID-ICU, SMDLTSWCI, RDSCI, DDMLSMVICP
# 26        ETSDMV, ATD, HDDSICU, MIND-USA, AUDDICU, AUPTICUPP, EDvsLSMENDS, ESDDVCIP, RUSGATICUD, AMTD, DIICU, RAEATICU, SPICE-III, AID-ICU, SMDLTSWCI, SEDCOM, RDSCI, DDMLSMVICP
# 27                 ETSDMV, ATD, HDDSICU, MIND-USA, AUDDICU, AUPTICUPP, EDvsLSMENDS, ESDDVCIP, RUSGATICUD, AMTD, DIICU, RAEATICU, SPICE-III, SEDCOM, SMDLTSWCI, RDSCI, DDMLSMVICP
# 28                           ETSDMV, ATD, HDDSICU, RUSGATICUD, AUDDICU, AUPTICUPP, EDvsLSMENDS, ESDDVCIP, AMTD, DIICU, RAEATICU, SPICE-III, SEDCOM, SMDLTSWCI, RDSCI, DDMLSMVICP
# 29                           ETSDMV, ATD, HDDSICU, RUSGATICUD, AUDDICU, AUPTICUPP, EDvsLSMENDS, ESDDVCIP, AMTD, DIICU, RAEATICU, SPICE-III, SEDCOM, SMDLTSWCI, RDSCI, DDMLSMVICP
# 30                                                                                                                                                            ESDDVCIP, ESCPARDS
# 31                                                                                                                                                            ESDDVCIP, LCOTARDS
# 32                                                                                                                                                              ESDDVCIP, MHNOCA
# 33                                                                                                                                                                        BTCSCA
# 34                                                                                                                                          OTCSCA, SPICE-III, HDDSICU, ESDDVCIP
# 35                                                              ETSDMV, HDDSICU, MIND-USA, EDvsLSMENDS, ESDDVCIP, DPSMVAS, DIICU, RAEATICU, SPICE-III, SEDCOM, RDSCI, DDMLSMVICP
